# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 778

# %%
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherdesc = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weatherdesc})

    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | cayenne
# Processing Record 3 of Set 1 | banda aceh
# Processing Record 4 of Set 1 | kyra
# Processing Record 5 of Set 1 | cherskiy
# Processing Record 6 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | svetlyy
# Processing Record 10 of Set 1 | flinders
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | grand forks
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | torbay
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | manokwari
# Processing Record 21 of Set 1 | pak chong
# Processing Record 22 of Set 1 | kahului
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | wilmington island
# Processing Record 26 of Set 1 | atambua
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | neiafu
# Processing Record 29 of Set 1 | saint george
# Processing Record 30 of Set 1 | port moresby
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 1 | lake havasu city
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | hovd
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | bougouni
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | husavik
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | kanniyakumari
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | santander
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | suntar
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | batagay-alyta
# Processing Record 1 of Set 2 | manihari
# Processing Record 2 of Set 2 | novikovo
# Processing Record 3 of Set 2 | verkhnyaya toyma
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | fort frances
# Processing Record 6 of Set 2 | thinadhoo
# Processing Record 7 of Set 2 | wladyslawowo
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | maryville
# Processing Record 11 of Set 2 | santa rosa
# Processing Record 12 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 2 | soyo
# Processing Record 14 of Set 2 | cabo san lucas
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | komsomolskiy
# Processing Record 18 of Set 2 | stephenville
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | parras
# City not found. Skipping...
# Processing Record 21 of Set 2 | haines junction
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 2 | ialibu
# Processing Record 25 of Set 2 | yarmouth
# Processing Record 26 of Set 2 | mbandaka
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 2 | abeche
# Processing Record 30 of Set 2 | kyabe
# Processing Record 31 of Set 2 | mayumba
# Processing Record 32 of Set 2 | meulaboh
# Processing Record 33 of Set 2 | gat
# Processing Record 34 of Set 2 | port blair
# Processing Record 35 of Set 2 | mount isa
# Processing Record 36 of Set 2 | kruisfontein
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | chuy
# Processing Record 39 of Set 2 | kavieng
# Processing Record 40 of Set 2 | mankono
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | waterloo
# Processing Record 43 of Set 2 | veraval
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | lazarev
# Processing Record 46 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 2 | jalu
# Processing Record 49 of Set 2 | antofagasta
# Processing Record 50 of Set 2 | moose factory
# Processing Record 1 of Set 3 | chimbote
# Processing Record 2 of Set 3 | tungor
# Processing Record 3 of Set 3 | lompoc
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | bridgetown
# Processing Record 6 of Set 3 | tiznit
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | cape town
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | kankaanpaa
# Processing Record 13 of Set 3 | mahina
# Processing Record 14 of Set 3 | kimberley
# Processing Record 15 of Set 3 | denpasar
# Processing Record 16 of Set 3 | gimli
# Processing Record 17 of Set 3 | cidreira
# Processing Record 18 of Set 3 | nalut
# Processing Record 19 of Set 3 | severo-kurilsk
# Processing Record 20 of Set 3 | richards bay
# Processing Record 21 of Set 3 | esperance
# Processing Record 22 of Set 3 | shestakovo
# Processing Record 23 of Set 3 | nelson bay
# Processing Record 24 of Set 3 | nueva helvecia
# Processing Record 25 of Set 3 | coquimbo
# Processing Record 26 of Set 3 | mufumbwe
# Processing Record 27 of Set 3 | santa cruz
# Processing Record 28 of Set 3 | kamenka
# Processing Record 29 of Set 3 | aitape
# Processing Record 30 of Set 3 | nantucket
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | merrill
# Processing Record 33 of Set 3 | pucallpa
# Processing Record 34 of Set 3 | nyurba
# Processing Record 35 of Set 3 | sorland
# Processing Record 36 of Set 3 | bairiki
# Processing Record 37 of Set 3 | salalah
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | mount gambier
# Processing Record 40 of Set 3 | bastogne
# Processing Record 41 of Set 3 | visnes
# Processing Record 42 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 3 | fallon
# Processing Record 45 of Set 3 | troitsko-pechorsk
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | anadyr
# Processing Record 48 of Set 3 | okhotsk
# Processing Record 49 of Set 3 | paamiut
# Processing Record 50 of Set 3 | carnarvon
# Processing Record 1 of Set 4 | dauphin
# Processing Record 2 of Set 4 | christchurch
# Processing Record 3 of Set 4 | auki
# Processing Record 4 of Set 4 | touros
# Processing Record 5 of Set 4 | lavrentiya
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | novobirilyussy
# Processing Record 8 of Set 4 | chapais
# Processing Record 9 of Set 4 | barrow
# Processing Record 10 of Set 4 | shimanovsk
# Processing Record 11 of Set 4 | lenine
# Processing Record 12 of Set 4 | poum
# Processing Record 13 of Set 4 | dakar
# Processing Record 14 of Set 4 | pleshanovo
# Processing Record 15 of Set 4 | shahe
# Processing Record 16 of Set 4 | pasni
# Processing Record 17 of Set 4 | mehamn
# Processing Record 18 of Set 4 | havoysund
# Processing Record 19 of Set 4 | igrim
# Processing Record 20 of Set 4 | madinat sittah uktubar
# Processing Record 21 of Set 4 | lazaro cardenas
# Processing Record 22 of Set 4 | yatou
# Processing Record 23 of Set 4 | erzurum
# Processing Record 24 of Set 4 | saint-pierre
# Processing Record 25 of Set 4 | tateyama
# Processing Record 26 of Set 4 | tigil
# Processing Record 27 of Set 4 | santa ines
# Processing Record 28 of Set 4 | basar
# Processing Record 29 of Set 4 | ndele
# Processing Record 30 of Set 4 | natal
# Processing Record 31 of Set 4 | grenfell
# Processing Record 32 of Set 4 | port hardy
# Processing Record 33 of Set 4 | daru
# Processing Record 34 of Set 4 | wanxian
# Processing Record 35 of Set 4 | shaowu
# Processing Record 36 of Set 4 | golyshmanovo
# Processing Record 37 of Set 4 | antalaha
# Processing Record 38 of Set 4 | zambezi
# Processing Record 39 of Set 4 | talnakh
# Processing Record 40 of Set 4 | udaipura
# Processing Record 41 of Set 4 | manono
# Processing Record 42 of Set 4 | whitehorse
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | los llanos de aridane
# Processing Record 45 of Set 4 | san patricio
# Processing Record 46 of Set 4 | araguatins
# City not found. Skipping...
# Processing Record 47 of Set 4 | lorengau
# Processing Record 48 of Set 4 | saskylakh
# Processing Record 49 of Set 4 | praia
# Processing Record 50 of Set 4 | moron
# Processing Record 1 of Set 5 | parnamirim
# Processing Record 2 of Set 5 | zhanakorgan
# Processing Record 3 of Set 5 | avarua
# Processing Record 4 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 5 of Set 5 | port elizabeth
# Processing Record 6 of Set 5 | chaa-khol
# City not found. Skipping...
# Processing Record 7 of Set 5 | saint-joseph
# Processing Record 8 of Set 5 | gravelbourg
# Processing Record 9 of Set 5 | omsukchan
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | bassano
# Processing Record 12 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 5 | codrington
# Processing Record 14 of Set 5 | taguatinga
# Processing Record 15 of Set 5 | dikson
# Processing Record 16 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 5 | jamestown
# Processing Record 18 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 5 | saint-philippe
# Processing Record 20 of Set 5 | baghdad
# Processing Record 21 of Set 5 | georgetown
# Processing Record 22 of Set 5 | qaanaaq
# Processing Record 23 of Set 5 | fort nelson
# Processing Record 24 of Set 5 | yaan
# Processing Record 25 of Set 5 | manaure
# Processing Record 26 of Set 5 | lagoa
# Processing Record 27 of Set 5 | kampot
# Processing Record 28 of Set 5 | puerto penasco
# Processing Record 29 of Set 5 | horn lake
# Processing Record 30 of Set 5 | borzya
# Processing Record 31 of Set 5 | murmansk
# Processing Record 32 of Set 5 | clyde river
# Processing Record 33 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 34 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 5 | sao felix do xingu
# Processing Record 36 of Set 5 | chokurdakh
# Processing Record 37 of Set 5 | rodnykove
# Processing Record 38 of Set 5 | klaksvik
# Processing Record 39 of Set 5 | plakhtiyivka
# Processing Record 40 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 41 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | chernyshevskiy
# Processing Record 44 of Set 5 | nizwa
# Processing Record 45 of Set 5 | jumla
# Processing Record 46 of Set 5 | gaoual
# Processing Record 47 of Set 5 | lebu
# Processing Record 48 of Set 5 | san ramon
# Processing Record 49 of Set 5 | conceicao do araguaia
# Processing Record 50 of Set 5 | kyzyl-suu
# Processing Record 1 of Set 6 | naryan-mar
# Processing Record 2 of Set 6 | vestmannaeyjar
# Processing Record 3 of Set 6 | faya
# Processing Record 4 of Set 6 | mahebourg
# Processing Record 5 of Set 6 | cuamba
# Processing Record 6 of Set 6 | luderitz
# Processing Record 7 of Set 6 | at-bashi
# Processing Record 8 of Set 6 | magadan
# Processing Record 9 of Set 6 | sicuani
# Processing Record 10 of Set 6 | gornopravdinsk
# Processing Record 11 of Set 6 | la ronge
# Processing Record 12 of Set 6 | bugulma
# Processing Record 13 of Set 6 | padang
# Processing Record 14 of Set 6 | bilibino
# Processing Record 15 of Set 6 | sinnamary
# Processing Record 16 of Set 6 | praia da vitoria
# Processing Record 17 of Set 6 | tasiilaq
# Processing Record 18 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 6 | prince rupert
# Processing Record 21 of Set 6 | sacramento
# Processing Record 22 of Set 6 | micheweni
# Processing Record 23 of Set 6 | alta floresta
# Processing Record 24 of Set 6 | wad rawah
# Processing Record 25 of Set 6 | xifeng
# Processing Record 26 of Set 6 | ye
# City not found. Skipping...
# Processing Record 27 of Set 6 | cerrito
# Processing Record 28 of Set 6 | constantine
# Processing Record 29 of Set 6 | khartoum
# Processing Record 30 of Set 6 | ilulissat
# Processing Record 31 of Set 6 | tomatlan
# Processing Record 32 of Set 6 | lively
# Processing Record 33 of Set 6 | kentau
# Processing Record 34 of Set 6 | pipri
# Processing Record 35 of Set 6 | askino
# Processing Record 36 of Set 6 | buraydah
# Processing Record 37 of Set 6 | flin flon
# Processing Record 38 of Set 6 | basco
# Processing Record 39 of Set 6 | sitka
# Processing Record 40 of Set 6 | senekal
# Processing Record 41 of Set 6 | darhan
# Processing Record 42 of Set 6 | bandarban
# Processing Record 43 of Set 6 | labuhan
# Processing Record 44 of Set 6 | bethel
# Processing Record 45 of Set 6 | plettenberg bay
# Processing Record 46 of Set 6 | sakakah
# Processing Record 47 of Set 6 | saldanha
# Processing Record 48 of Set 6 | saint-francois
# Processing Record 49 of Set 6 | fernandopolis
# Processing Record 50 of Set 6 | souillac
# Processing Record 1 of Set 7 | nome
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | pajapan
# Processing Record 4 of Set 7 | parkes
# Processing Record 5 of Set 7 | rochdale
# Processing Record 6 of Set 7 | neulengbach
# Processing Record 7 of Set 7 | longyearbyen
# Processing Record 8 of Set 7 | grindavik
# Processing Record 9 of Set 7 | cherkasskoye
# Processing Record 10 of Set 7 | baykit
# Processing Record 11 of Set 7 | koulamoutou
# Processing Record 12 of Set 7 | salinopolis
# Processing Record 13 of Set 7 | the valley
# Processing Record 14 of Set 7 | okandja
# City not found. Skipping...
# Processing Record 15 of Set 7 | necochea
# Processing Record 16 of Set 7 | riom
# Processing Record 17 of Set 7 | canico
# Processing Record 18 of Set 7 | dingle
# Processing Record 19 of Set 7 | homer
# Processing Record 20 of Set 7 | pevek
# Processing Record 21 of Set 7 | tuatapere
# Processing Record 22 of Set 7 | belyy yar
# Processing Record 23 of Set 7 | fastovetskaya
# Processing Record 24 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 7 | gasa
# Processing Record 26 of Set 7 | middletown
# Processing Record 27 of Set 7 | eureka
# Processing Record 28 of Set 7 | mahon
# Processing Record 29 of Set 7 | sterlibashevo
# Processing Record 30 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 7 | biak
# Processing Record 32 of Set 7 | porto novo
# Processing Record 33 of Set 7 | itarema
# Processing Record 34 of Set 7 | bogandinskiy
# Processing Record 35 of Set 7 | shimoda
# Processing Record 36 of Set 7 | hobyo
# Processing Record 37 of Set 7 | tucuman
# Processing Record 38 of Set 7 | parrita
# Processing Record 39 of Set 7 | litovko
# Processing Record 40 of Set 7 | victor harbor
# Processing Record 41 of Set 7 | sao filipe
# Processing Record 42 of Set 7 | krasnoselkup
# Processing Record 43 of Set 7 | andenes
# Processing Record 44 of Set 7 | les cayes
# Processing Record 45 of Set 7 | fortuna
# Processing Record 46 of Set 7 | khatanga
# Processing Record 47 of Set 7 | muros
# Processing Record 48 of Set 7 | soe
# Processing Record 49 of Set 7 | ust-tsilma
# Processing Record 50 of Set 7 | vostok
# Processing Record 1 of Set 8 | iranshahr
# Processing Record 2 of Set 8 | geraldton
# Processing Record 3 of Set 8 | iwanai
# Processing Record 4 of Set 8 | dafeng
# Processing Record 5 of Set 8 | kamina
# Processing Record 6 of Set 8 | pangnirtung
# Processing Record 7 of Set 8 | soldotna
# Processing Record 8 of Set 8 | margate
# Processing Record 9 of Set 8 | toungoo
# City not found. Skipping...
# Processing Record 10 of Set 8 | mezen
# Processing Record 11 of Set 8 | mollendo
# Processing Record 12 of Set 8 | salekhard
# Processing Record 13 of Set 8 | avera
# Processing Record 14 of Set 8 | verkhoyansk
# Processing Record 15 of Set 8 | alenquer
# Processing Record 16 of Set 8 | lasa
# Processing Record 17 of Set 8 | gidole
# Processing Record 18 of Set 8 | bursol
# City not found. Skipping...
# Processing Record 19 of Set 8 | manbij
# Processing Record 20 of Set 8 | polyarnyy
# Processing Record 21 of Set 8 | chicama
# Processing Record 22 of Set 8 | matelandia
# Processing Record 23 of Set 8 | colesberg
# Processing Record 24 of Set 8 | chiredzi
# Processing Record 25 of Set 8 | torzhok
# Processing Record 26 of Set 8 | vila franca do campo
# Processing Record 27 of Set 8 | hofn
# Processing Record 28 of Set 8 | beyla
# Processing Record 29 of Set 8 | leningradskiy
# Processing Record 30 of Set 8 | babushkin
# Processing Record 31 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 32 of Set 8 | otavi
# Processing Record 33 of Set 8 | kuching
# Processing Record 34 of Set 8 | tazovskiy
# Processing Record 35 of Set 8 | goderich
# Processing Record 36 of Set 8 | olafsvik
# Processing Record 37 of Set 8 | teya
# Processing Record 38 of Set 8 | faanui
# Processing Record 39 of Set 8 | emerald
# Processing Record 40 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 8 | zeya
# Processing Record 42 of Set 8 | wanning
# Processing Record 43 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 8 | mana
# Processing Record 45 of Set 8 | sao joao da barra
# Processing Record 46 of Set 8 | vardo
# Processing Record 47 of Set 8 | khani
# Processing Record 48 of Set 8 | sterling
# Processing Record 49 of Set 8 | berlevag
# Processing Record 50 of Set 8 | nouadhibou
# Processing Record 1 of Set 9 | san rafael
# Processing Record 2 of Set 9 | kokopo
# Processing Record 3 of Set 9 | muana
# Processing Record 4 of Set 9 | wuxue
# Processing Record 5 of Set 9 | sola
# Processing Record 6 of Set 9 | nezlobnaya
# Processing Record 7 of Set 9 | kijang
# Processing Record 8 of Set 9 | kaitangata
# Processing Record 9 of Set 9 | loikaw
# Processing Record 10 of Set 9 | portales
# Processing Record 11 of Set 9 | aguas formosas
# Processing Record 12 of Set 9 | tefe
# Processing Record 13 of Set 9 | hasaki
# Processing Record 14 of Set 9 | tessalit
# Processing Record 15 of Set 9 | itupiranga
# Processing Record 16 of Set 9 | arawa
# Processing Record 17 of Set 9 | bataipora
# Processing Record 18 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 9 | coihaique
# Processing Record 20 of Set 9 | matara
# Processing Record 21 of Set 9 | ukiah
# Processing Record 22 of Set 9 | huarmey
# Processing Record 23 of Set 9 | lodi
# Processing Record 24 of Set 9 | ostrovnoy
# Processing Record 25 of Set 9 | teguise
# Processing Record 26 of Set 9 | yamada
# Processing Record 27 of Set 9 | miranda
# Processing Record 28 of Set 9 | cururupu
# Processing Record 29 of Set 9 | tombouctou
# Processing Record 30 of Set 9 | zabid
# Processing Record 31 of Set 9 | rafaela
# Processing Record 32 of Set 9 | brae
# Processing Record 33 of Set 9 | zhigansk
# Processing Record 34 of Set 9 | bayevo
# Processing Record 35 of Set 9 | teluk nibung
# Processing Record 36 of Set 9 | sobolevo
# Processing Record 37 of Set 9 | mogoytuy
# Processing Record 38 of Set 9 | tautira
# Processing Record 39 of Set 9 | itoman
# Processing Record 40 of Set 9 | ixtapa
# Processing Record 41 of Set 9 | akhisar
# Processing Record 42 of Set 9 | shadrinsk
# Processing Record 43 of Set 9 | krasnovishersk
# Processing Record 44 of Set 9 | port lincoln
# Processing Record 45 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 9 | wuwei
# Processing Record 47 of Set 9 | phuket
# Processing Record 48 of Set 9 | katsuura
# Processing Record 49 of Set 9 | malpe
# Processing Record 50 of Set 9 | elbrus
# Processing Record 1 of Set 10 | acapulco
# Processing Record 2 of Set 10 | balkhash
# Processing Record 3 of Set 10 | san borja
# Processing Record 4 of Set 10 | mogocha
# Processing Record 5 of Set 10 | lagos
# Processing Record 6 of Set 10 | santo tomas
# Processing Record 7 of Set 10 | makat
# Processing Record 8 of Set 10 | outjo
# Processing Record 9 of Set 10 | maceio
# Processing Record 10 of Set 10 | tulsipur
# Processing Record 11 of Set 10 | tual
# Processing Record 12 of Set 10 | chabahar
# Processing Record 13 of Set 10 | mandiana
# Processing Record 14 of Set 10 | gurupi
# Processing Record 15 of Set 10 | gweta
# Processing Record 16 of Set 10 | griffith
# Processing Record 17 of Set 10 | ati
# Processing Record 18 of Set 10 | lishui
# Processing Record 19 of Set 10 | chara
# Processing Record 20 of Set 10 | srednekolymsk
# Processing Record 21 of Set 10 | dongsheng
# Processing Record 22 of Set 10 | uarini
# Processing Record 23 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 10 | rocha
# Processing Record 25 of Set 10 | povolzhskiy
# Processing Record 26 of Set 10 | panara
# Processing Record 27 of Set 10 | kadaya
# Processing Record 28 of Set 10 | hambantota
# Processing Record 29 of Set 10 | roros
# Processing Record 30 of Set 10 | bogotol
# Processing Record 31 of Set 10 | shitanjing
# Processing Record 32 of Set 10 | san fernando
# Processing Record 33 of Set 10 | ondjiva
# Processing Record 34 of Set 10 | codajas
# Processing Record 35 of Set 10 | port hedland
# Processing Record 36 of Set 10 | byron bay
# Processing Record 37 of Set 10 | vestmanna
# Processing Record 38 of Set 10 | bathsheba
# Processing Record 39 of Set 10 | maracaibo
# Processing Record 40 of Set 10 | zaoyang
# Processing Record 41 of Set 10 | hualmay
# Processing Record 42 of Set 10 | san cristobal
# Processing Record 43 of Set 10 | raudeberg
# Processing Record 44 of Set 10 | natitingou
# Processing Record 45 of Set 10 | bonaventure
# Processing Record 46 of Set 10 | ouegoa
# Processing Record 47 of Set 10 | luanda
# Processing Record 48 of Set 10 | qasigiannguit
# Processing Record 49 of Set 10 | mushie
# Processing Record 50 of Set 10 | verkhniy tagil
# Processing Record 1 of Set 11 | portland
# Processing Record 2 of Set 11 | kavaratti
# Processing Record 3 of Set 11 | almunecar
# Processing Record 4 of Set 11 | terni
# Processing Record 5 of Set 11 | taksimo
# Processing Record 6 of Set 11 | ozernovskiy
# Processing Record 7 of Set 11 | snasa
# Processing Record 8 of Set 11 | doembang nangbuat
# Processing Record 9 of Set 11 | hirtshals
# Processing Record 10 of Set 11 | inuvik
# Processing Record 11 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 12 of Set 11 | soni
# Processing Record 13 of Set 11 | melfort
# Processing Record 14 of Set 11 | cooma
# Processing Record 15 of Set 11 | karasjok
# Processing Record 16 of Set 11 | takapau
# Processing Record 17 of Set 11 | ancud
# Processing Record 18 of Set 11 | kholodnyy
# Processing Record 19 of Set 11 | nogales
# Processing Record 20 of Set 11 | half moon bay
# Processing Record 21 of Set 11 | vrangel
# Processing Record 22 of Set 11 | gryazi
# Processing Record 23 of Set 11 | santa isabel do rio negro
# Processing Record 24 of Set 11 | andapa
# Processing Record 25 of Set 11 | atar
# Processing Record 26 of Set 11 | rocky mountain house
# Processing Record 27 of Set 11 | hua hin
# Processing Record 28 of Set 11 | linhares
# Processing Record 29 of Set 11 | norman wells
# Processing Record 30 of Set 11 | chumikan
# Processing Record 31 of Set 11 | guerrero negro
# Processing Record 32 of Set 11 | kamphaeng phet
# Processing Record 33 of Set 11 | belaya gora
# Processing Record 34 of Set 11 | catemaco
# Processing Record 35 of Set 11 | jinchang
# Processing Record 36 of Set 11 | westport
# Processing Record 37 of Set 11 | grand gaube
# Processing Record 38 of Set 11 | brigantine
# Processing Record 39 of Set 11 | gryfice
# Processing Record 40 of Set 11 | nanzhang
# Processing Record 41 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 11 | pueblo bello
# Processing Record 43 of Set 11 | areosa
# Processing Record 44 of Set 11 | alice springs
# Processing Record 45 of Set 11 | college
# Processing Record 46 of Set 11 | pozo colorado
# Processing Record 47 of Set 11 | cody
# Processing Record 48 of Set 11 | chippewa falls
# Processing Record 49 of Set 11 | miri
# Processing Record 50 of Set 11 | isangel
# Processing Record 1 of Set 12 | waingapu
# Processing Record 2 of Set 12 | varlamovo
# Processing Record 3 of Set 12 | oktyabrskoye
# Processing Record 4 of Set 12 | gardabani
# Processing Record 5 of Set 12 | khandyga
# Processing Record 6 of Set 12 | banff
# Processing Record 7 of Set 12 | ginda
# Processing Record 8 of Set 12 | camacupa
# Processing Record 9 of Set 12 | la macarena
# Processing Record 10 of Set 12 | plainview
# Processing Record 11 of Set 12 | bambanglipuro
# Processing Record 12 of Set 12 | baillif
# Processing Record 13 of Set 12 | vydrino
# Processing Record 14 of Set 12 | te anau
# Processing Record 15 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 16 of Set 12 | nemuro
# Processing Record 17 of Set 12 | camana
# Processing Record 18 of Set 12 | boende
# Processing Record 19 of Set 12 | marsala
# Processing Record 20 of Set 12 | quime
# Processing Record 21 of Set 12 | chanute
# Processing Record 22 of Set 12 | nhamunda
# Processing Record 23 of Set 12 | maues
# Processing Record 24 of Set 12 | samur
# Processing Record 25 of Set 12 | corn island
# Processing Record 26 of Set 12 | mustasaari
# Processing Record 27 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 28 of Set 12 | nova serrana
# Processing Record 29 of Set 12 | rovaniemi
# Processing Record 30 of Set 12 | young
# Processing Record 31 of Set 12 | karlshamn
# Processing Record 32 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 12 | trincomalee
# Processing Record 34 of Set 12 | abapo
# Processing Record 35 of Set 12 | pacific grove
# Processing Record 36 of Set 12 | saint-louis
# Processing Record 37 of Set 12 | seoul
# Processing Record 38 of Set 12 | riverton
# Processing Record 39 of Set 12 | smithers
# Processing Record 40 of Set 12 | ulladulla
# Processing Record 41 of Set 12 | puerto narino
# Processing Record 42 of Set 12 | shingu
# Processing Record 43 of Set 12 | fremont
# Processing Record 44 of Set 12 | ust-nera
# Processing Record 45 of Set 12 | adrar
# Processing Record 46 of Set 12 | krasnopillya
# Processing Record 47 of Set 12 | bitung
# Processing Record 48 of Set 12 | atka
# City not found. Skipping...
# Processing Record 49 of Set 12 | asau
# Processing Record 50 of Set 12 | narsaq
# Processing Record 1 of Set 13 | coahuayana
# Processing Record 2 of Set 13 | athmallik
# Processing Record 3 of Set 13 | korla
# Processing Record 4 of Set 13 | springbok
# Processing Record 5 of Set 13 | oksovskiy
# Processing Record 6 of Set 13 | zhuhai
# Processing Record 7 of Set 13 | aklavik
# Processing Record 8 of Set 13 | teofilo otoni
# Processing Record 9 of Set 13 | naze
# Processing Record 10 of Set 13 | juneau
# Processing Record 11 of Set 13 | tyazhinskiy
# Processing Record 12 of Set 13 | port pirie
# Processing Record 13 of Set 13 | upata
# Processing Record 14 of Set 13 | the pas
# Processing Record 15 of Set 13 | felanitx
# Processing Record 16 of Set 13 | cockburn town
# Processing Record 17 of Set 13 | isetskoye
# Processing Record 18 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 13 | bulolo
# Processing Record 20 of Set 13 | baijiantan
# Processing Record 21 of Set 13 | romny
# Processing Record 22 of Set 13 | valleyview
# Processing Record 23 of Set 13 | japura
# Processing Record 24 of Set 13 | jacqueville
# Processing Record 25 of Set 13 | florida
# Processing Record 26 of Set 13 | ribeira grande
# Processing Record 27 of Set 13 | saint-georges
# Processing Record 28 of Set 13 | jaisalmer
# Processing Record 29 of Set 13 | jutai
# Processing Record 30 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 31 of Set 13 | kimbe
# Processing Record 32 of Set 13 | seydi
# Processing Record 33 of Set 13 | vinh
# Processing Record 34 of Set 13 | kassala
# Processing Record 35 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 13 | kaeo
# Processing Record 37 of Set 13 | camacha
# Processing Record 38 of Set 13 | beroroha
# Processing Record 39 of Set 13 | scarborough
# Processing Record 40 of Set 13 | kushmurun
# Processing Record 41 of Set 13 | payo
# Processing Record 42 of Set 13 | karratha
# Processing Record 43 of Set 13 | gravdal
# Processing Record 44 of Set 13 | ternate
# Processing Record 45 of Set 13 | alyangula
# Processing Record 46 of Set 13 | san andres
# Processing Record 47 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 48 of Set 13 | bubaque
# Processing Record 49 of Set 13 | kinna
# Processing Record 50 of Set 13 | houma
# Processing Record 1 of Set 14 | fergus falls
# Processing Record 2 of Set 14 | tepalcatepec
# Processing Record 3 of Set 14 | dondo
# Processing Record 4 of Set 14 | lahaina
# Processing Record 5 of Set 14 | longyan
# Processing Record 6 of Set 14 | bowen
# Processing Record 7 of Set 14 | paredon
# Processing Record 8 of Set 14 | basirpur
# Processing Record 9 of Set 14 | yasothon
# Processing Record 10 of Set 14 | basqal
# Processing Record 11 of Set 14 | beyneu
# Processing Record 12 of Set 14 | mirnyy
# Processing Record 13 of Set 14 | beringovskiy
# Processing Record 14 of Set 14 | himora
# City not found. Skipping...
# Processing Record 15 of Set 14 | mata
# Processing Record 16 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 14 | moa
# Processing Record 19 of Set 14 | bud
# Processing Record 20 of Set 14 | vermillion
# Processing Record 21 of Set 14 | akyab
# Processing Record 22 of Set 14 | san quintin
# Processing Record 23 of Set 14 | belmonte
# Processing Record 24 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 25 of Set 14 | san vicente
# Processing Record 26 of Set 14 | gunjur
# Processing Record 27 of Set 14 | viedma
# Processing Record 28 of Set 14 | sehithwa
# Processing Record 29 of Set 14 | susanville
# Processing Record 30 of Set 14 | machali
# Processing Record 31 of Set 14 | san juan del sur
# Processing Record 32 of Set 14 | goundam
# Processing Record 33 of Set 14 | vao
# Processing Record 34 of Set 14 | susuman
# Processing Record 35 of Set 14 | chengde
# Processing Record 36 of Set 14 | kutum
# Processing Record 37 of Set 14 | ayolas
# Processing Record 38 of Set 14 | coolum beach
# Processing Record 39 of Set 14 | negara
# Processing Record 40 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 41 of Set 14 | hoquiam
# Processing Record 42 of Set 14 | zilair
# Processing Record 43 of Set 14 | maragogi
# Processing Record 44 of Set 14 | nishihara
# Processing Record 45 of Set 14 | mogadishu
# Processing Record 46 of Set 14 | george town
# Processing Record 47 of Set 14 | churachandpur
# Processing Record 48 of Set 14 | berdigestyakh
# Processing Record 49 of Set 14 | ivybridge
# Processing Record 50 of Set 14 | hirara
# Processing Record 1 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 15 | kaniama
# Processing Record 3 of Set 15 | besenyszog
# Processing Record 4 of Set 15 | barstow
# Processing Record 5 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 15 | elizabeth city
# Processing Record 7 of Set 15 | solnechnyy
# Processing Record 8 of Set 15 | udachnyy
# Processing Record 9 of Set 15 | san carlos del zulia
# Processing Record 10 of Set 15 | puerto baquerizo moreno
# Processing Record 11 of Set 15 | druskininkai
# Processing Record 12 of Set 15 | muriwai beach
# Processing Record 13 of Set 15 | binga
# Processing Record 14 of Set 15 | broome
# Processing Record 15 of Set 15 | bocaiuva
# Processing Record 16 of Set 15 | sokolovyy
# Processing Record 17 of Set 15 | kandrian
# Processing Record 18 of Set 15 | el rosario
# Processing Record 19 of Set 15 | yenotayevka
# Processing Record 20 of Set 15 | coos bay
# Processing Record 21 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 22 of Set 15 | ambovombe
# Processing Record 23 of Set 15 | puerto colombia
# Processing Record 24 of Set 15 | doha
# Processing Record 25 of Set 15 | robinson
# Processing Record 26 of Set 15 | macedo de cavaleiros
# Processing Record 27 of Set 15 | ahuimanu
# Processing Record 28 of Set 15 | seoni
# Processing Record 29 of Set 15 | yerkoy
# Processing Record 30 of Set 15 | lugo
# Processing Record 31 of Set 15 | tulare
# Processing Record 32 of Set 15 | lantawan
# Processing Record 33 of Set 15 | bobon
# Processing Record 34 of Set 15 | fairbanks
# Processing Record 35 of Set 15 | constitucion
# Processing Record 36 of Set 15 | dunhua
# Processing Record 37 of Set 15 | bafq
# Processing Record 38 of Set 15 | camopi
# Processing Record 39 of Set 15 | hay river
# Processing Record 40 of Set 15 | alofi
# Processing Record 41 of Set 15 | shiyan
# Processing Record 42 of Set 15 | konstantinovka
# Processing Record 43 of Set 15 | changji
# Processing Record 44 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 15 | chunhuhub
# Processing Record 46 of Set 15 | mpongwe
# Processing Record 47 of Set 15 | wewak
# Processing Record 48 of Set 15 | ouadda
# Processing Record 49 of Set 15 | bandarbeyla
# Processing Record 50 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 16 | kelvington
# Processing Record 3 of Set 16 | waipawa
# Processing Record 4 of Set 16 | kieta
# Processing Record 5 of Set 16 | laguna
# Processing Record 6 of Set 16 | pringsewu
# Processing Record 7 of Set 16 | hirado
# Processing Record 8 of Set 16 | aguada
# Processing Record 9 of Set 16 | vagur
# Processing Record 10 of Set 16 | dryden
# Processing Record 11 of Set 16 | tabuk
# Processing Record 12 of Set 16 | makakilo city
# Processing Record 13 of Set 16 | alappuzha
# Processing Record 14 of Set 16 | marzuq
# Processing Record 15 of Set 16 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 16 | menongue
# Processing Record 17 of Set 16 | champasak
# Processing Record 18 of Set 16 | qaqortoq
# Processing Record 19 of Set 16 | ewo
# Processing Record 20 of Set 16 | canutama
# Processing Record 21 of Set 16 | spaichingen
# Processing Record 22 of Set 16 | santa marta
# Processing Record 23 of Set 16 | vila velha
# Processing Record 24 of Set 16 | roald
# Processing Record 25 of Set 16 | yemelyanovo
# Processing Record 26 of Set 16 | vyartsilya
# Processing Record 27 of Set 16 | jizan
# Processing Record 28 of Set 16 | warrenton
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Butaritari      KI   3.0707  172.7902     80.73        81           6
# 1        Cayenne      GF   4.9333  -52.3333     82.40        89          75
# 2     Banda Aceh      ID   5.5577   95.3222     79.84        81          30
# 3           Kyra      RU  49.5776  111.9753      0.64        87          92
# 4       Cherskiy      RU  68.7500  161.3000     -2.72        74          65
# ..           ...     ...      ...       ...       ...       ...         ...
# 712        Roald      NO  62.5833    6.1333     26.60        46           0
# 713  Yemelyanovo      RU  56.1681   92.6767     35.60        51           0
# 714   Vyartsilya      RU  62.1764   30.6930     15.55        96         100
# 715        Jizan      SA  17.3333   42.6667     80.60        61          20
# 716    Warrenton      ZA -28.1140   24.8475     88.05        28          14
#
#      Wind Speed Current Description
# 0         17.63           clear sky
# 1         14.97          light rain
# 2          6.38    scattered clouds
# 3          2.35     overcast clouds
# 4          2.17       broken clouds
# ..          ...                 ...
# 712       14.97           clear sky
# 713        8.95           clear sky
# 714        7.61     overcast clouds
# 715       12.66          few clouds
# 716        5.53          few clouds
#
# [717 rows x 9 columns]

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
